head>
#   <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
#   <title>Таблица</title>
#   <style type="text/css">
#    TABLE {
#     width: 300px; /* Ширина таблицы */
#     border: 2px solid black; /* Рамка вокруг таблицы */
#     background: silver; /* Цвет фона таблицы */
#    }
#    TD, TH {
#     text-align: center; /* Выравнивание по центру */
#     padding: 3px; /* Поля вокруг содержимого ячеек */
#    }
#    TH {
#     background: #4682b4; /* Цвет фона */
#     color: white; /* Цвет текста */
#     border-bottom: 2px solid black; /* Линия снизу */
#    }
#    .lc {
#     font-weight: bold; /* Жирное начертание текста */
#     text-align: left; /* Выравнивание по левому краю */
#    }
#   </style>
#  </head>
#  <body>
#   <table cellspacing="0">
# 		<tr>
# 		<td colspan="2"><b>Площа</b></td>
# 		</tr>
# 		<tr>
# 			<td>Загалом</td>
# 			<td>69 700 км² </td>
# 		</tr>
# 		<tr>
# 			<td colspan="2"><b>Населення</b></td>
# 		</tr>
# 		<tr>
# 			<td>Оцінка 2020</td>
# 			<td>3 716 858 осіб</td>
# 		</tr>
# 		<tr>
# 			<td>Перепис 2015 </td>
# 			<td>3 729 500 осіб</td>
# 		</tr>
# 		<tr>
# 		<td>Густота</td>
# 		<td>53,5/км²</td>
# 		</tr>
#      </table>
#       <h2>Головні свята Грузії</h2>
# <ul>
#  <li>Мцхетоба-Светіцховлоба – 14 жовтня </li>
#  <li>Нінооба – 1 червня </li>
#  <li>Тамароба – 14 травня </li>
#  <li>День Святого Георгія – 23 листопада </li>
#  <li>День незалежності Грузії – 26 травня </li>
#  <li>День національної єдності – 9 квітня </li>
#  <li>Ртвелі </li>
#  <li>Новий рік </li>
# </ul>

# %%
from IPython.display import Image 

display(Image(url='https://upload.wikimedia.org/wikipedia/commons/f/f6/Svaneti%2C_georgia.jpg',
              width = 1000) 
 
       )
# Out:
# <img src="https://upload.wikimedia.org/wikipedia/commons/f/f6/Svaneti%2C_georgia.jpg" width="1000"/>

# %%
from IPython.display import Image 

display(Image(url='https://upload.wikimedia.org/wikipedia/commons/e/ee/Svetitskhoveli1.jpg',
              width = 1000) 
 
       )
# Out:
# <img src="https://upload.wikimedia.org/wikipedia/commons/e/ee/Svetitskhoveli1.jpg" width="1000"/>

# %%
from IPython.display import Image 

display(Image(url='https://upload.wikimedia.org/wikipedia/commons/6/6f/Keselo%2C_Tusheti.jpg',
              width = 1000) 
 
       )
# Out:
# <img src="https://upload.wikimedia.org/wikipedia/commons/6/6f/Keselo%2C_Tusheti.jpg" width="1000"/>

# %%
from IPython.display import Image 

display(Image(url='https://upload.wikimedia.org/wikipedia/commons/3/37/Batumi_Botanical_Garden._Black_Sea.jpg',
              width = 1000) 
 
       )
# Out:
# <img src="https://upload.wikimedia.org/wikipedia/commons/3/37/Batumi_Botanical_Garden._Black_Sea.jpg" width="1000"/>

# %% [markdown]
# </table>
# <h2>Завдання № 8 Грузія</h2>

# %%
import random
n=9
amax=99
a=[]
for j in range(n):
    a.append(random.randint(1,amax))
print(a)
a.sort()
a.reverse()
print("Список елементів від найбільшого до найменшого")
for j in range(n):
    Min=a[0]
    if a[j]<Min:
        Min=a[j]
        
print(a)
# Out:
# [54, 27, 71, 50, 16, 21, 13, 75, 83]
# Список елементів від найбільшого до найменшого
# [83, 75, 71, 54, 50, 27, 21, 16, 13]
